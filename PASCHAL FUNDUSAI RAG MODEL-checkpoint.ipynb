# %%
# !pip install --upgrade --quiet  langchain-google-genai

# %%
# !pip install --upgrade langchain
# Out:
# ...
#    ---------------------------------------- 0.0/807.5 kB ? eta -:--:--
#     --------------------------------------- 10.2/807.5 kB ? eta -:--:--
#    - ------------------------------------- 30.7/807.5 kB 435.7 kB/s eta 0:00:02
#    - ------------------------------------- 41.0/807.5 kB 245.8 kB/s eta 0:00:04
#    -- ------------------------------------ 61.4/807.5 kB 328.2 kB/s eta 0:00:03
#    ----- -------------------------------- 112.6/807.5 kB 467.6 kB/s eta 0:00:02
#    ----- -------------------------------- 122.9/807.5 kB 423.5 kB/s eta 0:00:02
#    -------- ----------------------------- 174.1/807.5 kB 523.5 kB/s eta 0:00:02
#    --------- ---------------------------- 194.6/807.5 kB 512.0 kB/s eta 0:00:02
#    ------------ ------------------------- 256.0/807.5 kB 582.4 kB/s eta 0:00:01
#    -------------- ----------------------- 307.2/807.5 kB 655.5 kB/s eta 0:00:01
#    -------------- ----------------------- 317.4/807.5 kB 614.4 kB/s eta 0:00:01
# ...

# %%
# !pip install --upgrade --quiet  langchain-google-genai

# %%
from langchain_google_genai import GoogleGenerativeAI

# %%
from getpass import getpass

api_key = getpass()
# Out:
#  ········

# %%
llm = GoogleGenerativeAI(model="models/text-bison-001", google_api_key=api_key)
print(
    llm.invoke(
        "What does it mean to be successful in a capitalist society"
    )
)
# Out:
# There is no one answer to the question of what it means to be successful in a capitalist society, as success is a subjective term that can mean different things to different people. However, some common factors that are often associated with success in a capitalist society include financial wealth, material possessions, career achievement, and social status.
#
# Financial wealth is often seen as a key indicator of success in a capitalist society. This is because money can be used to purchase material possessions, which can in turn be used to gain social status and improve one's quality of life. However, it is important to note that financial wealth is not the only measure of success, and that there are many other ways to achieve a fulfilling and meaningful life.
#
# ...

# %%
llm = GoogleGenerativeAI(model="models/text-bison-001", google_api_key=api_key)
print(
    llm.invoke(
        "What does it mean to be successful in a capitalist society"
    )
)
# Out:
# There is no one definitive answer to the question of what it means to be successful in a capitalist society. However, some common factors that are often associated with success include financial wealth, social status, and career achievement.
#
# Financial wealth is often seen as a key indicator of success in a capitalist society. This is because money can provide access to a variety of resources and opportunities that can improve one's quality of life. For example, money can be used to buy a home in a safe neighborhood, send children to good schools, and provide for one's family. In addition, financial wealth can give people the freedom to pursue their own interests and passions, without having to worry about financial constraints.
#
# ...

# %%
# !pip install --upgrade --quiet  langchain sentence_transformers

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

model_name = "BAAI/bge-base-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}# set True to compute cosine similarity

hf = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle

# %%
with open('embedding.pkl', 'wb') as file:
    pickle.dump(hf, file)

# %%
with open('embedding.pkl', 'rb') as file:
    embedding = pickle.load(file)

# %%
embeddings = embedding.embed_query("Iam going crazy building this RAG model")
embeddings
# Out:
# [0.012566383928060532,
#  -0.02095487341284752,
#  -0.005041743628680706,
#  0.005985572002828121,
#  0.04639606922864914,
#  -0.017062639817595482,
#  0.020030565559864044,
#  0.0029986323788762093,
#  -0.025935105979442596,
#  -0.04237724840641022,
#  -0.02427125722169876,
#  0.0005397193017415702,
#  -0.06817132979631424,
#  0.07060108333826065,
#  -0.007073031738400459,
#  0.07468601316213608,
#  0.038726869970560074,
#  0.010867692530155182,
#  0.021472090855240822,
#  0.0005533871008083224,
#  0.022100569680333138,
#  -0.01366640068590641,
#  -0.000582230684813112,
#  0.014102942310273647,
#  0.019909266382455826,
#  0.0036375022027641535,
#  0.02370414510369301,
#  -0.03209551423788071,
#  -0.05522201955318451,
#  -0.03202267363667488,
#  0.01934700272977352,
#  -0.03574598953127861,
#  -0.01827205903828144,
#  -0.022043094038963318,
#  0.007396237924695015,
#  -0.0125294029712677,
#  -0.08094283193349838,
#  0.0011747139506042004,
#  0.02812795154750347,
# ...

# %%
len(embedding)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 len(embedding)
#
# TypeError: object of type 'HuggingFaceBgeEmbeddings' has no len()

# %%
import urllib
import warnings
from pathlib import Path as p
from pprint import pprint

import pandas as pd
from langchain import PromptTemplate
from langchain.chains.question_answering import load_qa_chain
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA



warnings.filterwarnings("ignore")
# restart python kernal if issues with langchain import.

# %%
pip install PyPDF

# %%
pdf_loader = PyPDFLoader("C:\\Users\\mgbec\\Documents\\SELF HELP BOOKS\\LAWS OF HUMAN NATURE.pdf")
pages = pdf_loader.load_and_split()
print(pages[5].page_content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 pdf_loader = PyPDFLoader("C:\\Users\\mgbec\\Documents\\SELF HELP BOOKS\\LAWS OF HUMAN NATURE.pdf")
#       2 pages = pdf_loader.load_and_split()
#       3 print(pages[5].page_content)
#
# File ~\anaconda3\Lib\site-packages\langchain_community\document_loaders\pdf.py:157, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images)
#     153 except ImportError:
#     154     raise ImportError(
#     155         "pypdf package not found, please install it with " "`pip install pypdf`"
#     156     )
# --> 157 super().__init__(file_path, headers=headers)
#     158 self.parser = PyPDFParser(password=password, extract_images=extract_images)
#
# File ~\anaconda3\Lib\site-packages\langchain_community\document_loaders\pdf.py:100, in BasePDFLoader.__init__(self, file_path, headers)
# ...
